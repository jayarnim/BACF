# %%
MODEL_CLS = "bamf"
COMB = "prod"
DATASET = "movielens"
STRATEGY = "pointwise"
PATH_WORK_DIR = "../../.."

# %%
if DATASET=="abeauty":
    NUM_USERS = 3819
    NUM_ITEMS = 1581
    FILTER = "default"
    MAX_LEN = None
elif DATASET=="amusic":
    NUM_USERS = 5541
    NUM_ITEMS = 3568
    FILTER = "default"
    MAX_LEN = None
elif DATASET=="lastfm":
    NUM_USERS = 1892
    NUM_ITEMS = 17632
    FILTER = "default"
    MAX_LEN = None
elif DATASET=="movielens":
    NUM_USERS = 610
    NUM_ITEMS = 9724
    FILTER = "tfidf"
    MAX_LEN = 400
else:
    raise ValueError()

ANCHOR = "user"

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\RESEARCH\2024-2 지능정보시스템학회 추계학술대회\BAMF

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Config

# %%
import pandas as pd
from components import histories
from pointwiseBayes import config, datamodule, trainer, evaluator, utils
import bacf

# %%
PATH = f"./config/{MODEL_CLS}_{STRATEGY}.yaml"
cfg = config.build(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/movielens.csv"
df = pd.read_csv(PATH)

# %%
kwargs = dict(
    df=df,
    percentile=0.9,
)

utils.desc.main(**kwargs)
# Out:
# number of user: 610
# number of item: 9724
# total interaction: 100836
# interaction density: 1.7000 %
# max interaction of user: 2698
# max interaction of item: 329
# top 10.0 % interaction of user: 400.3
# top 10.0 % interaction of item: 27.0
# mean interaction of user: 165
# mean interaction of item: 10

# %%
kwargs = dict(
    df=df,
    cfg=cfg.datamodule,
)

dataloaders, trn = datamodule.build(**kwargs)

# %%
kwargs = dict(
    df=trn,
    num_users=NUM_USERS,
    num_items=NUM_ITEMS,
    anchor=ANCHOR,
    filter=FILTER,
    max_len=MAX_LEN,
)

histories_cls = histories.Histories(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    histories=histories_cls,
    num_users=NUM_USERS,
    num_items=NUM_ITEMS,
    comb=COMB,
    **cfg.model.params,
)

model = bacf.bamf.BayesianAttentionalMatrixFactorization(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 18
# BEST SCORE: 0.5317

# %%
kwargs = dict(
    records=records,
    suptitle="BAMF Training History",
    trn="BCE",
    val="NDCG@10",
    figsize=(7,3),
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Test

# %%
kwargs = dict(
    model=model,
    cutoff=[5,10,15,20,25,50],
)

msr = evaluator.build(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST:   0%|          | 0/986 [00:00<?, ?it/s]
# TST: 100%|██████████| 986/986 [00:07<00:00, 129.58it/s]

# %%
metrics_sheet
# Out:
#     k  hit_ratio  precision    recall       map      ndcg
# 0   5   0.875410   0.427869  0.302408  0.238959  0.505380
# 1  10   0.944262   0.335574  0.426347  0.292909  0.512452
# 2  15   0.962295   0.285246  0.503701  0.318131  0.526564
# 3  20   0.978689   0.250164  0.564212  0.333507  0.540096
# 4  25   0.986885   0.222164  0.601337  0.342457  0.547449
# 5  50   0.996721   0.150754  0.712758  0.366311  0.575740

# %% [markdown]
# # Save

# %%
PATH = f'./checkpoints/{DATASET}/{MODEL_CLS}/{COMB}_{STRATEGY}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
