# %%
MODEL_CLS = "bacf"
COMB = None
HIDDEN_DIM = (
    [128, 64, 32]
    if COMB=="cat"
    else [64, 32]
)
DATASET = "movielens"
STRATEGY = "pointwise"
PATH_WORK_DIR = "../../.."

# %%
if DATASET=="abeauty":
    NUM_USERS = 3819
    NUM_ITEMS = 1581
    FILTER = "default"
    MAX_LEN = None
elif DATASET=="amusic":
    NUM_USERS = 5541
    NUM_ITEMS = 3568
    FILTER = "default"
    MAX_LEN = None
elif DATASET=="lastfm":
    NUM_USERS = 1892
    NUM_ITEMS = 17632
    FILTER = "default"
    MAX_LEN = None
elif DATASET=="movielens":
    NUM_USERS = 610
    NUM_ITEMS = 9724
    FILTER = "tfidf"
    MAX_LEN = 400
else:
    raise ValueError()

ANCHOR = "user"

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\RESEARCH\2025-2 MDPI\BACF

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Config

# %%
import pandas as pd
from components import histories
from pointwiseBayes import config, datamodule, trainer, evaluator, utils
import bacf

# %%
PATH = f"./config/{MODEL_CLS}_{STRATEGY}.yaml"
cfg = config.build(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/{DATASET}.csv"
df = pd.read_csv(PATH)

# %%
kwargs = dict(
    df=df,
    percentile=0.9,
)

utils.desc.main(**kwargs)
# Out:
# number of user: 610
# number of item: 9724
# total interaction: 100836
# interaction density: 1.7000 %
# max interaction of user: 2698
# max interaction of item: 329
# top 10.0 % interaction of user: 400.3
# top 10.0 % interaction of item: 27.0
# mean interaction of user: 165
# mean interaction of item: 10

# %%
kwargs = dict(
    df=df,
    cfg=cfg.datamodule,
)

dataloaders, trn = datamodule.build(**kwargs)

# %%
kwargs = dict(
    df=trn,
    num_users=NUM_USERS,
    num_items=NUM_ITEMS,
    anchor=ANCHOR,
    filter=FILTER,
    max_len=MAX_LEN,
)

histories_cls = histories.Histories(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    histories=histories_cls,
    num_users=NUM_USERS,
    num_items=NUM_ITEMS,
    hidden_dim=HIDDEN_DIM,
    comb=COMB,
    **cfg.model.params,
)

model = bacf.bacf.BayesianAttentionalCollaborativeFiltering(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 21
# BEST SCORE: 0.5479

# %%
kwargs = dict(
    records=records,
    suptitle="BACF Training History",
    trn="BCE",
    val="NDCG@10",
    figsize=(7,3),
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Test

# %%
kwargs = dict(
    model=model,
    cutoff=[5,10,15,20,25,50],
)

msr = evaluator.build(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 986/986 [00:14<00:00, 68.77it/s]

# %%
metrics_sheet
# Out:
#     k  hit_ratio  precision    recall       map      ndcg
# 0   5   0.878689   0.441639  0.326255  0.264089  0.529319
# 1  10   0.957377   0.334098  0.435947  0.312713  0.525685
# 2  15   0.975410   0.282842  0.518333  0.339167  0.540701
# 3  20   0.986885   0.246803  0.572079  0.354403  0.552268
# 4  25   0.991803   0.220262  0.610140  0.363968  0.560909
# 5  50   0.995082   0.146426  0.708736  0.384833  0.585759

# %% [markdown]
# # Save

# %%
PATH = f'./checkpoints/{DATASET}/{MODEL_CLS}/{COMB}_{STRATEGY}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
